# %%
x = var('x')
solve ( x^3 - x == 7*x^(2) - 7,x)
# Out:
# [x == 7, x == -1, x == 1]

# %%
t = var('t')
solve (abs(t - 7)>3, t)
# Out:
# [[t < 4], [10 < t]]

# %%
x, y= var('x, y')
solve ([2*x + y == 17, x - 3*y == -16], x, y)
# Out:
# [[x == 5, y == 7]]

# %%
x = var('x')
a = (exp(x) - cos(x))
find_root(a, -pi/2, 0)
# Out:
# 0.0

# %%
x = var('x')
a = (exp(x) - cos(x))
find_root(a, -pi/2, 0.00001)
# Out:
# -1.142669808738535e-15

# %%
x = var('x')
a = (exp(x) - cos(x))
p = plot(a)
show(p)
# Out:
# Graphics object consisting of 1 graphics primitive
